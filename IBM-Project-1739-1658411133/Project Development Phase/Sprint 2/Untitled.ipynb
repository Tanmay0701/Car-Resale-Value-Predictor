# %%
import pandas as pd;

# %%
df=pd.read_csv("autos.csv",encoding="latin-1")
# Out:
# C:\Users\suriy\AppData\Local\Temp\ipykernel_22376\3745257280.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("autos.csv",encoding="latin-1")

# %%
df
# Out:
#              dateCrawled                                          name  \
# 0       24-03-2016 11.52                                    Golf_3_1.6
# 1       24-03-2016 10.58                          A5_Sportback_2.7_Tdi
# 2       14-03-2016 12.52                Jeep_Grand_Cherokee_"Overland"
# 3       17-03-2016 16.54                            GOLF_4_1_4__3TÜRER
# 4       31-03-2016 17.25                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                  ...                                           ...
# 371534  14-03-2016 17.48                    Suche_t4___vito_ab_6_sitze
# 371535  05-03-2016 19.56         Smart_smart_leistungssteigerung_100ps
# 371536  19-03-2016 18.57            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371537  20-03-2016 19.41                        VW_Golf_Kombi_1_9l_TDI
# 371538  07-03-2016 19.39  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType    price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df.abtest.unique()
# Out:
# array(['test', 'control', nan, 'benzin'], dtype=object)

# %%
df.lastSeen.unique()
# Out:
# array(['07-04-2016 3.16', '07-04-2016 1.46', '05-04-2016 12.47', ...,
#        '08-03-2016 20.43', '08-03-2016 21.28', '18-03-2016 11.30'],
#       dtype=object)

# %%
deleteList=["nrOfPictures","lastSeen","offerType","seller","dateCrawled","dateCreated"]
df.drop(deleteList,axis=1,inplace=True)

# %%
hpUnique=df.powerPS.unique();

# %%
hpUnique.sort()

# %%
hpUnique
# Out:
# array([0.0000e+00, 1.0000e+00, 2.0000e+00, 3.0000e+00, 4.0000e+00,
#        5.0000e+00, 6.0000e+00, 7.0000e+00, 8.0000e+00, 9.0000e+00,
#        1.0000e+01, 1.1000e+01, 1.2000e+01, 1.3000e+01, 1.4000e+01,
#        1.5000e+01, 1.6000e+01, 1.7000e+01, 1.8000e+01, 1.9000e+01,
#        2.0000e+01, 2.1000e+01, 2.2000e+01, 2.3000e+01, 2.4000e+01,
#        2.5000e+01, 2.6000e+01, 2.7000e+01, 2.8000e+01, 2.9000e+01,
#        3.0000e+01, 3.1000e+01, 3.2000e+01, 3.3000e+01, 3.4000e+01,
#        3.5000e+01, 3.6000e+01, 3.7000e+01, 3.8000e+01, 3.9000e+01,
#        4.0000e+01, 4.1000e+01, 4.2000e+01, 4.3000e+01, 4.4000e+01,
#        4.5000e+01, 4.6000e+01, 4.7000e+01, 4.8000e+01, 4.9000e+01,
#        5.0000e+01, 5.1000e+01, 5.2000e+01, 5.3000e+01, 5.4000e+01,
#        5.5000e+01, 5.6000e+01, 5.7000e+01, 5.8000e+01, 5.9000e+01,
#        6.0000e+01, 6.1000e+01, 6.2000e+01, 6.3000e+01, 6.4000e+01,
#        6.5000e+01, 6.6000e+01, 6.7000e+01, 6.8000e+01, 6.9000e+01,
# ...

# %%
df = df[(df.powerPS > 60) & (df.powerPS < 500)]
df.shape
# Out:
# (290191, 14)

# %%
df.isnull().sum()
# Out:
# name                       0
# price                      0
# abtest                     0
# vehicleType            18903
# yearOfRegistration         0
# gearbox                 4989
# powerPS                    0
# model                  11640
# kilometer                  0
# monthOfRegistration        0
# fuelType               17375
# brand                      0
# notRepairedDamage      41447
# postalCode                 0
# dtype: int64

# %%
df.dropna(how = "all")
# Out:
#                                                      name    price   abtest  \
# 1                                    A5_Sportback_2.7_Tdi  18300.0     test
# 2                          Jeep_Grand_Cherokee_"Overland"   9800.0     test
# 3                                      GOLF_4_1_4__3TÜRER   1500.0     test
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic   3600.0     test
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...    650.0     test
# ...                                                   ...      ...      ...
# 371531                                       turbo_defekt   3200.0  control
# 371535              Smart_smart_leistungssteigerung_100ps   1199.0     test
# 371536                 Volkswagen_Multivan_T4_TDI_7DC_UY2   9200.0     test
# 371537                             VW_Golf_Kombi_1_9l_TDI   3400.0     test
# 371538       BMW_M135i_vollausgestattet_NP_52.720____Euro  28990.0  control
#
# ...

# %%
df["yearOfRegistration"].max()
# Out:
# 9999.0

# %%
df = df[(df.yearOfRegistration > 1980) & (df.yearOfRegistration < 2019)]
df.shape
# Out:
# (288119, 14)

# %%
df
# Out:
#                                                      name    price   abtest  \
# 1                                    A5_Sportback_2.7_Tdi  18300.0     test
# 2                          Jeep_Grand_Cherokee_"Overland"   9800.0     test
# 3                                      GOLF_4_1_4__3TÜRER   1500.0     test
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic   3600.0     test
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...    650.0     test
# ...                                                   ...      ...      ...
# 371531                                       turbo_defekt   3200.0  control
# 371535              Smart_smart_leistungssteigerung_100ps   1199.0     test
# 371536                 Volkswagen_Multivan_T4_TDI_7DC_UY2   9200.0     test
# 371537                             VW_Golf_Kombi_1_9l_TDI   3400.0     test
# 371538       BMW_M135i_vollausgestattet_NP_52.720____Euro  28990.0  control
#
# ...

# %%
priceRange=df.price.unique()
priceRange.sort()
priceRange.mean()
# Out:
# 82550.00327300731

# %%
df = df[(df.price > 200) & (df.price < 75000)]
df.shape
# Out:
# (279216, 14)

# %%
df.monthOfRegistration.unique()
# Out:
# array([ 5.,  8.,  6.,  7., 10.,  0., 12., 11.,  2.,  3.,  1.,  4.,  9.])

# %%
df = df[(df.monthOfRegistration >= 1) & (df.monthOfRegistration <= 12)]
df.shape
# Out:
# (263765, 14)

# %%
df.notRepairedDamage.isnull().sum()
# Out:
# 30581

# %%
sdf=df.copy()
ldf=sdf.drop_duplicates(['price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox',
       'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType',
       'brand', 'notRepairedDamage', 'postalCode'])
ldf.shape
# Out:
# (254553, 14)

# %%
sdf.dropna(how="any",inplace=True)
sdf.shape
# Out:
# (215255, 14)

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# ...

# %%
df.notRepairedDamage.replace(to_replace="ja",value="1",inplace=True)

# %%
df.notRepairedDamage.replace(to_replace="nein",value="0",inplace=True)

# %%
df.notRepairedDamage.replace(to_replace="NaN",value="2",inplace=True)

# %%
fuelType=['diesel', 'benzin','lpg', 'andere', 'hybrid', 'cng',
       'elektro']

# %%
for fuel in fuelType:
    df.fuelType.replace(to_replace=fuel,value=fuelType.index(fuel),inplace=True)

# %%
df
# Out:
#                                                      name    price   abtest  \
# 1                                    A5_Sportback_2.7_Tdi  18300.0     test
# 2                          Jeep_Grand_Cherokee_"Overland"   9800.0     test
# 3                                      GOLF_4_1_4__3TÜRER   1500.0     test
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic   3600.0     test
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...    650.0     test
# ...                                                   ...      ...      ...
# 371531                                       turbo_defekt   3200.0  control
# 371535              Smart_smart_leistungssteigerung_100ps   1199.0     test
# 371536                 Volkswagen_Multivan_T4_TDI_7DC_UY2   9200.0     test
# 371537                             VW_Golf_Kombi_1_9l_TDI   3400.0     test
# 371538       BMW_M135i_vollausgestattet_NP_52.720____Euro  28990.0  control
#
# ...

# %%
modelList=['grand', 'golf', 'fabia', '3er', '2_reihe', 'c_max',
       '3_reihe', 'passat', 'navara', 'twingo', 'a_klasse', 'scirocco',
       '5er', 'meriva', 'andere', 'c4', 'civic', 'e_klasse', 'kadett',
       'one', 'fortwo', 'clio', '1er', 'b_klasse', 'punto', 'a8', 'jetta',
       'astra', 'c_klasse', 'micra', 'vito', 'sprinter', '156', 'escort',
       'forester', 'xc_reihe', 'fiesta', 'scenic', 'a1', 'transporter',
       'focus', 'a4', 'tt', 'a6', 'jazz', 'omega', 'polo', 'slk', '7er',
       'combo', '80', '147', 'glk', 'z_reihe', 'sportage', 'sorento',
       'ibiza', 'mustang', 'eos', 'touran', 'getz', 'insignia', 'almera',
       'megane', 'a3', 'r19', 'mondeo', 'cordoba', 'colt', 'impreza',
       'vectra', 'lupo', 'berlingo', 'm_klasse', 'tiguan', 'i_reihe',
       '6_reihe', 'up', 'ceed', 'kangoo', '5_reihe', 'yeti', 'octavia',
       'zafira', 'mii', 'rx_reihe', 'corsa', '6er', 'modus', 'panda',
       'beetle', 'rio', 'touareg', 'logan', 'caddy', 'spider', 's_max',
       'a2', 'x_reihe', 'a5', 'galaxy', 'c3', 'viano', 's_klasse',
       '1_reihe', 'sharan', 'avensis', 'sl', 'roomster', 'q5', 'santa',
       'leon', 'cooper', '4_reihe', 'laguna', 'ptcruiser', 'clk',
       'primera', 'espace', 'exeo', '159', 'transit', 'juke', 'ka', 'v40',
       'carisma', 'accord', 'corolla', 'lanos', 'phaeton', 'boxster',
       'verso', 'rav', 'kuga', 'qashqai', 'swift', 'picanto', 'superb',
       'stilo', 'alhambra', '911', 'm_reihe', 'roadster', 'ypsilon',
       'galant', 'justy', '90', 'sirion', 'signum', 'crossfire', 'duster',
       'v50', 'mx_reihe', 'discovery', 'c_reihe', 'v_klasse', 'yaris',
       'c5', 'aygo', 'cc', 'carnival', 'fusion', 'bora', 'agila', 'cl',
       'tigra', '300c', '500', '100', 'q3', 'cr_reihe', 'spark', 'x_type',
       'ducato', 's_type', 'x_trail', 'toledo', 'altea', 'voyager',
       'matiz', 'v70', 'bravo', 'range_rover', 'forfour', 'tucson', 'fox',
       'q7', 'c1', 'jimny', 'cx_reihe', 'cayenne', 'wrangler', 'lybra',
       'range_rover_sport', 'lancer', 'freelander', 'captiva', 'c2',
       'range_rover_evoque', 'sandero', 'note', 'antara', '900',
       'defender', 'cherokee', 'clubman', 'legacy', 'pajero', 'auris',
       'niva', 's60', 'nubira', 'vivaro', 'g_klasse', 'lodgy', '850',
       'serie_2', 'calibra', 'charade', 'croma', 'cuore', 'citigo',
       'outlander', 'gl', 'doblo', 'musa', 'kaefer', 'amarok', 'arosa',
       '9000', 'kalos', 'v60', 'aveo', '200', '145', 'b_max', 'delta',
       'rangerover', 'materia', 'terios', 'move', 'kalina', 'i3', 'kappa',
       'samara', 'serie_3', 'seicento', 'discovery_sport']

# %%
for model in modelList:
    df.model.replace(to_replace=model,value=int(modelList.index(model)) ,inplace=True)

# %%
df
# Out:
#                                                      name    price   abtest  \
# 1                                    A5_Sportback_2.7_Tdi  18300.0     test
# 2                          Jeep_Grand_Cherokee_"Overland"   9800.0     test
# 3                                      GOLF_4_1_4__3TÜRER   1500.0     test
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic   3600.0     test
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...    650.0     test
# ...                                                   ...      ...      ...
# 371531                                       turbo_defekt   3200.0  control
# 371535              Smart_smart_leistungssteigerung_100ps   1199.0     test
# 371536                 Volkswagen_Multivan_T4_TDI_7DC_UY2   9200.0     test
# 371537                             VW_Golf_Kombi_1_9l_TDI   3400.0     test
# 371538       BMW_M135i_vollausgestattet_NP_52.720____Euro  28990.0  control
#
# ...

# %%
gearBoxType=['manuell','automatik']
for gear in gearBoxType:
    df.gearbox.replace(to_replace=gear,value=int(gearBoxType.index(gear)) ,inplace=True)

# %%
df
# Out:
#                                                      name    price   abtest  \
# 1                                    A5_Sportback_2.7_Tdi  18300.0     test
# 2                          Jeep_Grand_Cherokee_"Overland"   9800.0     test
# 3                                      GOLF_4_1_4__3TÜRER   1500.0     test
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic   3600.0     test
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...    650.0     test
# ...                                                   ...      ...      ...
# 371531                                       turbo_defekt   3200.0  control
# 371535              Smart_smart_leistungssteigerung_100ps   1199.0     test
# 371536                 Volkswagen_Multivan_T4_TDI_7DC_UY2   9200.0     test
# 371537                             VW_Golf_Kombi_1_9l_TDI   3400.0     test
# 371538       BMW_M135i_vollausgestattet_NP_52.720____Euro  28990.0  control
#
# ...

# %%
vehicleTypeList=['coupe', 'suv', 'kleinwagen', 'limousine', 'cabrio', 'bus', 'kombi','andere']

# %%
for veh in vehicleTypeList:
    df.vehicleType.replace(to_replace=veh,value=int(vehicleTypeList.index(veh)) ,inplace=True)

# %%
df
# Out:
#                                                      name    price   abtest  \
# 1                                    A5_Sportback_2.7_Tdi  18300.0     test
# 2                          Jeep_Grand_Cherokee_"Overland"   9800.0     test
# 3                                      GOLF_4_1_4__3TÜRER   1500.0     test
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic   3600.0     test
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...    650.0     test
# ...                                                   ...      ...      ...
# 371531                                       turbo_defekt   3200.0  control
# 371535              Smart_smart_leistungssteigerung_100ps   1199.0     test
# 371536                 Volkswagen_Multivan_T4_TDI_7DC_UY2   9200.0     test
# 371537                             VW_Golf_Kombi_1_9l_TDI   3400.0     test
# 371538       BMW_M135i_vollausgestattet_NP_52.720____Euro  28990.0  control
#
# ...

# %%
abTestList=['test', 'control']

# %%
for ab in abTestList:
    df.abtest.replace(to_replace=ab,value=int(abTestList.index(ab)) ,inplace=True)

# %%
df
# Out:
#                                                      name    price  abtest  \
# 1                                    A5_Sportback_2.7_Tdi  18300.0       0
# 2                          Jeep_Grand_Cherokee_"Overland"   9800.0       0
# 3                                      GOLF_4_1_4__3TÜRER   1500.0       0
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic   3600.0       0
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...    650.0       0
# ...                                                   ...      ...     ...
# 371531                                       turbo_defekt   3200.0       1
# 371535              Smart_smart_leistungssteigerung_100ps   1199.0       0
# 371536                 Volkswagen_Multivan_T4_TDI_7DC_UY2   9200.0       0
# 371537                             VW_Golf_Kombi_1_9l_TDI   3400.0       0
# 371538       BMW_M135i_vollausgestattet_NP_52.720____Euro  28990.0       1
#
# ...

# %%
df.name.unique()
# Out:
# array(['A5_Sportback_2.7_Tdi', 'Jeep_Grand_Cherokee_"Overland"',
#        'GOLF_4_1_4__3TÜRER', ..., 'Smart_smart_leistungssteigerung_100ps',
#        'VW_Golf_Kombi_1_9l_TDI',
#        'BMW_M135i_vollausgestattet_NP_52.720____Euro'], dtype=object)

# %%
df.drop(['name'],axis=1,inplace=True)

# %%
df
# Out:
#           price  abtest  vehicleType  yearOfRegistration  gearbox  powerPS  \
# 1       18300.0       0          0.0              2011.0      0.0    190.0
# 2        9800.0       0          1.0              2004.0      1.0    163.0
# 3        1500.0       0          2.0              2001.0      0.0     75.0
# 4        3600.0       0          2.0              2008.0      0.0     69.0
# 5         650.0       0          3.0              1995.0      0.0    102.0
# ...         ...     ...          ...                 ...      ...      ...
# 371531   3200.0       1          3.0              2004.0      0.0    225.0
# 371535   1199.0       0          4.0              2000.0      1.0    101.0
# 371536   9200.0       0          5.0              1996.0      0.0    102.0
# 371537   3400.0       0          6.0              2002.0      0.0    100.0
# 371538  28990.0       1          3.0              2013.0      0.0    320.0
#
# ...

# %%
df.brand.unique()
# Out:
# array(['audi', 'jeep', 'volkswagen', 'skoda', 'bmw', 'peugeot', 'ford',
#        'mazda', 'nissan', 'renault', 'mercedes_benz', 'opel', 'citroen',
#        'honda', 'mini', 'smart', 'fiat', 'seat', 'subaru', 'volvo',
#        'mitsubishi', 'hyundai', 'alfa_romeo', 'kia', 'lancia', 'porsche',
#        'toyota', 'dacia', 'suzuki', 'chrysler', 'sonstige_autos',
#        'jaguar', 'rover', 'saab', 'chevrolet', 'daihatsu', 'land_rover',
#        'lada', 'daewoo'], dtype=object)

# %%
brandlist=['audi', 'jeep', 'volkswagen', 'skoda', 'bmw', 'peugeot', 'ford',
       'mazda', 'nissan', 'renault', 'mercedes_benz', 'opel', 'citroen',
       'honda', 'mini', 'smart', 'fiat', 'seat', 'subaru', 'volvo',
       'mitsubishi', 'hyundai', 'alfa_romeo', 'kia', 'lancia', 'porsche',
       'toyota', 'dacia', 'suzuki', 'chrysler', 'sonstige_autos',
       'jaguar', 'rover', 'saab', 'chevrolet', 'daihatsu', 'land_rover',
       'lada', 'daewoo']
for brand in brandlist:
    df.brand.replace(to_replace=brand,value=int(brandlist.index(brand)) ,inplace=True)

# %%
df
# Out:
#           price  abtest  vehicleType  yearOfRegistration  gearbox  powerPS  \
# 1       18300.0       0          0.0              2011.0      0.0    190.0
# 2        9800.0       0          1.0              2004.0      1.0    163.0
# 3        1500.0       0          2.0              2001.0      0.0     75.0
# 4        3600.0       0          2.0              2008.0      0.0     69.0
# 5         650.0       0          3.0              1995.0      0.0    102.0
# ...         ...     ...          ...                 ...      ...      ...
# 371531   3200.0       1          3.0              2004.0      0.0    225.0
# 371535   1199.0       0          4.0              2000.0      1.0    101.0
# 371536   9200.0       0          5.0              1996.0      0.0    102.0
# 371537   3400.0       0          6.0              2002.0      0.0    100.0
# 371538  28990.0       1          3.0              2013.0      0.0    320.0
#
#         model kilometer  monthOfRegistration  fuelType  brand  \
# ...

# %%
df.model.mode()
# Out:
# 0    1.0
# Name: model, dtype: float64

# %%
# for column in df.columns:
#     df[column].fillna(df[column].mode()[0], inplace=True)

# %%
# sdf=df.copy()
# ldf=sdf.drop_duplicates(['price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox',
#        'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType',
#        'brand', 'notRepairedDamage', 'postalCode'])
# ldf.shape
# Out:
# (257080, 13)

# %%
print(sdf)
# Out:
#           price  abtest  vehicleType  yearOfRegistration  gearbox  powerPS  \
# 1       18300.0       0          0.0              2011.0      0.0    190.0
# 2        9800.0       0          1.0              2004.0      1.0    163.0
# 3        1500.0       0          2.0              2001.0      0.0     75.0
# 4        3600.0       0          2.0              2008.0      0.0     69.0
# 5         650.0       0          3.0              1995.0      0.0    102.0
# ...         ...     ...          ...                 ...      ...      ...
# 371531   3200.0       1          3.0              2004.0      0.0    225.0
# 371535   1199.0       0          4.0              2000.0      1.0    101.0
# 371536   9200.0       0          5.0              1996.0      0.0    102.0
# 371537   3400.0       0          6.0              2002.0      0.0    100.0
# 371538  28990.0       1          3.0              2013.0      0.0    320.0
#
#         model kilometer  monthOfRegistration  fuelType  brand  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
ydf=sdf.drop(['abtest', 'vehicleType', 'yearOfRegistration', 'gearbox',
       'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType',
       'brand', 'notRepairedDamage', 'postalCode'],axis=1,inplace=False)


xdf=sdf.drop(['price'],axis=1,inplace=False)

# %%
xdf
# Out:
#         abtest  vehicleType  yearOfRegistration  gearbox  powerPS  model  \
# 1            0          0.0              2011.0      0.0    190.0    NaN
# 2            0          1.0              2004.0      1.0    163.0    0.0
# 3            0          2.0              2001.0      0.0     75.0    1.0
# 4            0          2.0              2008.0      0.0     69.0    2.0
# 5            0          3.0              1995.0      0.0    102.0    3.0
# ...        ...          ...                 ...      ...      ...    ...
# 371531       1          3.0              2004.0      0.0    225.0  111.0
# 371535       0          4.0              2000.0      1.0    101.0   20.0
# 371536       0          5.0              1996.0      0.0    102.0   39.0
# 371537       0          6.0              2002.0      0.0    100.0    1.0
# 371538       1          3.0              2013.0      0.0    320.0  141.0
#
#        kilometer  monthOfRegistration  fuelType  brand notRepairedDamage  \
# ...

# %%
ydf
# Out:
#           price
# 1       18300.0
# 2        9800.0
# 3        1500.0
# 4        3600.0
# 5         650.0
# ...         ...
# 371531   3200.0
# 371535   1199.0
# 371536   9200.0
# 371537   3400.0
# 371538  28990.0
#
# [266338 rows x 1 columns]

# %%
sc=MinMaxScaler(feature_range=(0,1))
new_x = sc.fit_transform(xdf)
new_y=sc.fit_transform(ydf)

# %%
new_x.shape
# Out:
# (266338, 12)

# %%
new_y.shape
# Out:
# (266338, 1)

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import numpy as np

# %%
X_train,X_test,Y_train,Y_test = train_test_split(new_x, new_y, train_size=0.5)
regressor = RandomForestRegressor(n_estimators = 100, max_depth = 10)

# %%
X_train.shape,Y_train.shape
# Out:
# ((133169, 12), (133169, 1))

# %%
regressor.fit(X_train,np.ravel(Y_train,order='C'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 regressor.fit(X_train,np.ravel(Y_train,order='C'))
#
# File C:\Python310\lib\site-packages\sklearn\ensemble\_forest.py:331, in BaseForest.fit(self, X, y, sample_weight)
#     329 if issparse(y):
#     330     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331 X, y = self._validate_data(
#     332     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333 )
#     334 if sample_weight is not None:
#     335     sample_weight = _check_sample_weight(sample_weight, X)
#
# File C:\Python310\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
# ...

# %%
regressor.predict(X_test)

# %%
regressor.score(X_test,Y_test)
